# %%
import csv, json 
import os.path
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import librosa
import librosa.display
import IPython.display as ipd
import math

# use LateX fonts
plt.rcParams.update({
  "text.usetex": True,
  "font.family": "Helvetica"
})

# %% [markdown]
# # Initialize constants

# %%
#session_nums = [session_num for session_num in range(300, 493) if session_num not in [342, 394, 398, 460, 443]]
AUDIO_FEATURES = ['f0_median', 'f0_mean', 'f0_range', 'rmse_median', 'rmse_mean', 'zcr_median', 'zcr_mean', 'ber_median', 'ber_mean']
PATH_TO_AUDIO = "interviews/"
FILE_NAME_SUFFIX = "_AUDIO_SLICED_30.0s.wav"
PHQ_CSV_FILE = "participants_info/phq_scores.csv"
PARTICIPANTS_INFO = {}
PARTICIPANTS_INFO_EXIST_ON_DISK = False
SAMPLING_RATE = 16000
SPLIT_FREQUENCY = 500

FRAME_SIZE = 512
HOP_LENGTH = 256

# %% [markdown]
# # check if feature extraction results already exist on disk

# %%
if os.path.exists('extracted_feature_results/results.json'):
    PARTICIPANTS_INFO_EXIST_ON_DISK = True
    with open('extracted_feature_results/results.json', 'r') as jsonFile:
        PARTICIPANTS_INFO = json.load(jsonFile)
    print(PARTICIPANTS_INFO_EXIST_ON_DISK)
# Out:
# True

# %%
audio, sr = librosa.load("interviews/467_AUDIO_SLICED_30.0s.wav", sr=SAMPLING_RATE)
S_interview = librosa.stft(audio, n_fft=FRAME_SIZE, hop_length=HOP_LENGTH)
ber_interview = band_energy_ratio(S_interview, SPLIT_FREQUENCY, SAMPLING_RATE)
print(ber_interview)
fig, ax = plt.subplots()
img = librosa.display.specshow(librosa.amplitude_to_db(S_interview,ref=np.max),y_axis='log', x_axis='time', ax=ax, hop_length=HOP_LENGTH, sr=SAMPLING_RATE)
ax.set_title('Power spectrogram')
fig.colorbar(img, ax=ax, format="%+2.0f dB")


print(np.mean(ber_interview))
# Out:
# <ipython-input-6-445255d50dd3>:16: RuntimeWarning: invalid value encountered in float_scalars
#   band_energy_ratio_current_frame = sum_power_low_frequencies / sum_power_high_frequencies
# C:\Users\oliver\anaconda3\lib\site-packages\librosa\core\spectrum.py:1641: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   warnings.warn(
# [5636.094   7032.8745  5464.373   ...  102.84553 1015.2912   375.94998]
# nan

# %% [markdown]
# # Loading participants phq scores

# %%
def createParticipantInfoFromCsv(csv_file: str) -> dict:
    outer_dict = {}
    with open(csv_file) as csvFile:
        csv_reader = csv.reader(csvFile, delimiter=',')
        line_count = 0
        for row in csv_reader:
            line_count += 1
            #or row[0] == '387'
            if line_count == 1:
                continue
            inner_dict = {}
            if row[1] == "1":
                inner_dict.update({"depressed": "yes"})
            else:
                inner_dict.update({"depressed": "no"})
            inner_dict.update({"phq_score": row[2]})
            if row[3] == "1":
                inner_dict.update({"gender": "male"})
            else:
                inner_dict.update({"gender": "female"})
            outer_dict[row[0]] = inner_dict
        
    return outer_dict

# %% [markdown]
# # store info in dict

# %%
if PARTICIPANTS_INFO_EXIST_ON_DISK == False:
    PARTICIPANTS_INFO = createParticipantInfoFromCsv(PHQ_CSV_FILE)

# %% [markdown]
# # Loading audio Files

# %%
if PARTICIPANTS_INFO_EXIST_ON_DISK == False:
    for k, v in PARTICIPANTS_INFO.items():
        loaded_audio, _ = librosa.load(f"{PATH_TO_AUDIO}{k}{FILE_NAME_SUFFIX}", sr=SAMPLING_RATE, offset=20.0)
        v.update({"loaded_audio_30s": loaded_audio})
        print(f"loaded audio file for participant {k}!")
    print("loaded all audio files with librosa!")
# Out:
# loaded audio file for participant 302!
# loaded audio file for participant 307!
# loaded audio file for participant 331!
# loaded audio file for participant 335!
# loaded audio file for participant 346!
# loaded audio file for participant 367!
# loaded audio file for participant 377!
# loaded audio file for participant 381!
# loaded audio file for participant 382!
# loaded audio file for participant 388!
# loaded audio file for participant 389!
# loaded audio file for participant 390!
# loaded audio file for participant 395!
# loaded audio file for participant 403!
# loaded audio file for participant 404!
# loaded audio file for participant 406!
# loaded audio file for participant 413!
# loaded audio file for participant 417!
# loaded audio file for participant 418!
# loaded audio file for participant 420!
# loaded audio file for participant 422!
# loaded audio file for participant 436!
# loaded audio file for participant 439!
# loaded audio file for participant 440!
# loaded audio file for participant 451!
# loaded audio file for participant 458!
# loaded audio file for participant 472!
# loaded audio file for participant 476!
# loaded audio file for participant 477!
# loaded audio file for participant 482!
# loaded audio file for participant 483!
# loaded audio file for participant 484!
# loaded audio file for participant 489!
# loaded audio file for participant 490!
# loaded audio file for participant 492!
# loaded audio file for participant 300!
# loaded audio file for participant 301!
# loaded audio file for participant 306!
# loaded audio file for participant 308!
# loaded audio file for participant 309!
# loaded audio file for participant 311!
# loaded audio file for participant 314!
# loaded audio file for participant 323!
# loaded audio file for participant 329!
# loaded audio file for participant 332!
# loaded audio file for participant 334!
# loaded audio file for participant 337!
# loaded audio file for participant 349!
# loaded audio file for participant 354!
# loaded audio file for participant 359!
# loaded audio file for participant 361!
# loaded audio file for participant 365!
# loaded audio file for participant 373!
# loaded audio file for participant 378!
# loaded audio file for participant 384!
# loaded audio file for participant 387!
# loaded audio file for participant 396!
# loaded audio file for participant 399!
# loaded audio file for participant 405!
# loaded audio file for participant 407!
# loaded audio file for participant 408!
# loaded audio file for participant 410!
# loaded audio file for participant 411!
# loaded audio file for participant 421!
# loaded audio file for participant 424!
# loaded audio file for participant 431!
# loaded audio file for participant 432!
# loaded audio file for participant 435!
# loaded audio file for participant 438!
# loaded audio file for participant 442!
# loaded audio file for participant 450!
# loaded audio file for participant 452!
# loaded audio file for participant 453!
# loaded audio file for participant 461!
# loaded audio file for participant 462!
# loaded audio file for participant 465!
# loaded audio file for participant 466!
# loaded audio file for participant 467!
# loaded audio file for participant 469!
# loaded audio file for participant 470!
# loaded audio file for participant 480!
# loaded audio file for participant 481!
# loaded audio file for participant 303!
# loaded audio file for participant 304!
# loaded audio file for participant 305!
# loaded audio file for participant 310!
# loaded audio file for participant 312!
# loaded audio file for participant 313!
# loaded audio file for participant 315!
# loaded audio file for participant 316!
# loaded audio file for participant 317!
# loaded audio file for participant 318!
# loaded audio file for participant 319!
# loaded audio file for participant 320!
# loaded audio file for participant 321!
# loaded audio file for participant 322!
# loaded audio file for participant 324!
# loaded audio file for participant 325!
# loaded audio file for participant 326!
# loaded audio file for participant 327!
# loaded audio file for participant 328!
# loaded audio file for participant 330!
# loaded audio file for participant 333!
# loaded audio file for participant 336!
# loaded audio file for participant 338!
# loaded audio file for participant 339!
# loaded audio file for participant 340!
# loaded audio file for participant 341!
# loaded audio file for participant 343!
# loaded audio file for participant 344!
# loaded audio file for participant 345!
# loaded audio file for participant 347!
# loaded audio file for participant 348!
# loaded audio file for participant 350!
# loaded audio file for participant 351!
# loaded audio file for participant 352!
# loaded audio file for participant 353!
# loaded audio file for participant 355!
# loaded audio file for participant 356!
# loaded audio file for participant 357!
# loaded audio file for participant 358!
# loaded audio file for participant 360!
# loaded audio file for participant 362!
# loaded audio file for participant 363!
# loaded audio file for participant 364!
# loaded audio file for participant 366!
# loaded audio file for participant 368!
# loaded audio file for participant 369!
# loaded audio file for participant 370!
# loaded audio file for participant 371!
# loaded audio file for participant 372!
# loaded audio file for participant 374!
# loaded audio file for participant 375!
# loaded audio file for participant 376!
# loaded audio file for participant 379!
# loaded audio file for participant 380!
# loaded audio file for participant 383!
# loaded audio file for participant 385!
# loaded audio file for participant 386!
# loaded audio file for participant 391!
# loaded audio file for participant 392!
# loaded audio file for participant 393!
# loaded audio file for participant 397!
# loaded audio file for participant 400!
# loaded audio file for participant 401!
# loaded audio file for participant 402!
# loaded audio file for participant 409!
# loaded audio file for participant 412!
# loaded audio file for participant 414!
# loaded audio file for participant 415!
# loaded audio file for participant 416!
# loaded audio file for participant 419!
# loaded audio file for participant 423!
# loaded audio file for participant 425!
# loaded audio file for participant 426!
# loaded audio file for participant 427!
# loaded audio file for participant 428!
# loaded audio file for participant 429!
# loaded audio file for participant 430!
# loaded audio file for participant 433!
# loaded audio file for participant 434!
# loaded audio file for participant 437!
# loaded audio file for participant 441!
# loaded audio file for participant 443!
# loaded audio file for participant 444!
# loaded audio file for participant 445!
# loaded audio file for participant 446!
# loaded audio file for participant 447!
# loaded audio file for participant 448!
# loaded audio file for participant 449!
# loaded audio file for participant 454!
# loaded audio file for participant 455!
# loaded audio file for participant 456!
# loaded audio file for participant 457!
# loaded audio file for participant 459!
# loaded audio file for participant 463!
# loaded audio file for participant 464!
# loaded audio file for participant 468!
# loaded audio file for participant 471!
# loaded audio file for participant 473!
# loaded audio file for participant 474!
# loaded audio file for participant 475!
# loaded audio file for participant 478!
# loaded audio file for participant 479!
# loaded audio file for participant 485!
# loaded audio file for participant 486!
# loaded audio file for participant 487!
# loaded audio file for participant 488!
# loaded audio file for participant 491!
# loaded all audio files with librosa!

# %% [markdown]
# # functions for calculating band energy ratio

# %%
def calculate_split_frequency_bin(split_frequency, sample_rate, num_frequency_bins):
    """Infer the frequency bin associated to a given split frequency."""
    
    frequency_range = sample_rate / 2
    frequency_delta_per_bin = frequency_range / num_frequency_bins
    split_frequency_bin = math.floor(split_frequency / frequency_delta_per_bin)
    return int(split_frequency_bin)

# %%
# map split frequency to frequency bin
def band_energy_ratio(spectrogram, split_frequency, sample_rate):
    """Calculate band energy ratio with a given split frequency."""
    
    split_frequency_bin = calculate_split_frequency_bin(split_frequency, sample_rate, len(spectrogram[0]))
    band_energy_ratio = []
    
    # calculate power spectrogram
    power_spectrogram = np.abs(spectrogram) ** 2
    power_spectrogram = power_spectrogram.T
    
    # calculate BER value for each frame
    for frame in power_spectrogram:
        sum_power_low_frequencies = frame[:split_frequency_bin].sum()
        sum_power_high_frequencies = frame[split_frequency_bin:].sum()
        band_energy_ratio_current_frame = sum_power_low_frequencies / sum_power_high_frequencies
        band_energy_ratio.append(band_energy_ratio_current_frame)
    
    return np.array(band_energy_ratio)

# %% [markdown]
# # calculate audio features

# %%
if PARTICIPANTS_INFO_EXIST_ON_DISK == False:
    for k, v in PARTICIPANTS_INFO.items():
        rmse_audio = librosa.feature.rms(v['loaded_audio_30s'], frame_length=FRAME_SIZE, hop_length=HOP_LENGTH)[0]
        rmse_median = np.median(rmse_audio)
        rmse_mean = np.mean(rmse_audio)
        zcr_audio = librosa.feature.zero_crossing_rate(v['loaded_audio_30s'], frame_length=FRAME_SIZE, hop_length=HOP_LENGTH)[0]
        zcr_median = np.median(zcr_audio)
        zcr_mean = np.mean(zcr_audio)
        f0, _, _ = librosa.pyin(v['loaded_audio_30s'], fmin=50, fmax=500, frame_length=FRAME_SIZE, hop_length=HOP_LENGTH)
        f0_no_nans = f0[~np.isnan(f0)]
        f0_median = np.median(f0_no_nans)
        f0_mean = np.mean(f0_no_nans)
        f0_range = np.max(f0_no_nans) - np.min(f0_no_nans)
        S_interview = librosa.stft(v['loaded_audio_30s'], n_fft=FRAME_SIZE, hop_length=HOP_LENGTH)
        ber_interview = band_energy_ratio(S_interview, SPLIT_FREQUENCY, SAMPLING_RATE)
        ber_median = np.median(ber_interview)
        ber_mean = np.mean(ber_interview)

        v.update({"f0_median": f0_median})
        v.update({"f0_mean": f0_mean})
        v.update({"f0_range": f0_range})
        v.update({"zcr_median": zcr_median})
        v.update({"zcr_mean": zcr_mean})
        v.update({"rmse_median": rmse_median})
        v.update({"rmse_mean": rmse_mean})
        v.update({"ber_median": ber_median})
        v.update({"ber_mean": ber_mean})
        print(f"calculated audio features for participant {k}!")
    print("calculated all audio features with librosa!")
# Out:
# calculated audio features for participant 302!
# calculated audio features for participant 307!
# calculated audio features for participant 331!
# calculated audio features for participant 335!
# calculated audio features for participant 346!
# calculated audio features for participant 367!
# calculated audio features for participant 377!
# calculated audio features for participant 381!
# calculated audio features for participant 382!
# calculated audio features for participant 388!
# calculated audio features for participant 389!
# calculated audio features for participant 390!
# calculated audio features for participant 395!
# calculated audio features for participant 403!
# calculated audio features for participant 404!
# calculated audio features for participant 406!
# calculated audio features for participant 413!
# calculated audio features for participant 417!
# calculated audio features for participant 418!
# calculated audio features for participant 420!
# calculated audio features for participant 422!
# calculated audio features for participant 436!
# calculated audio features for participant 439!
# calculated audio features for participant 440!
# calculated audio features for participant 451!
# calculated audio features for participant 458!
# calculated audio features for participant 472!
# calculated audio features for participant 476!
# calculated audio features for participant 477!
# calculated audio features for participant 482!
# calculated audio features for participant 483!
# calculated audio features for participant 484!
# calculated audio features for participant 489!
# calculated audio features for participant 490!
# calculated audio features for participant 492!
# calculated audio features for participant 300!
# calculated audio features for participant 301!
# calculated audio features for participant 306!
# calculated audio features for participant 308!
# calculated audio features for participant 309!
# calculated audio features for participant 311!
# calculated audio features for participant 314!
# calculated audio features for participant 323!
# calculated audio features for participant 329!
# calculated audio features for participant 332!
# calculated audio features for participant 334!
# calculated audio features for participant 337!
# calculated audio features for participant 349!
# calculated audio features for participant 354!
# calculated audio features for participant 359!
# calculated audio features for participant 361!
# calculated audio features for participant 365!
# calculated audio features for participant 373!
# calculated audio features for participant 378!
# calculated audio features for participant 384!
# <ipython-input-14-445255d50dd3>:16: RuntimeWarning: invalid value encountered in float_scalars
#   band_energy_ratio_current_frame = sum_power_low_frequencies / sum_power_high_frequencies
# calculated audio features for participant 387!
# calculated audio features for participant 396!
# calculated audio features for participant 399!
# calculated audio features for participant 405!
# calculated audio features for participant 407!
# calculated audio features for participant 408!
# calculated audio features for participant 410!
# calculated audio features for participant 411!
# calculated audio features for participant 421!
# calculated audio features for participant 424!
# calculated audio features for participant 431!
# calculated audio features for participant 432!
# calculated audio features for participant 435!
# calculated audio features for participant 438!
# calculated audio features for participant 442!
# calculated audio features for participant 450!
# calculated audio features for participant 452!
# calculated audio features for participant 453!
# calculated audio features for participant 461!
# calculated audio features for participant 462!
# calculated audio features for participant 465!
# calculated audio features for participant 466!
# calculated audio features for participant 467!
# calculated audio features for participant 469!
# calculated audio features for participant 470!
# calculated audio features for participant 480!
# calculated audio features for participant 481!
# calculated audio features for participant 303!
# calculated audio features for participant 304!
# calculated audio features for participant 305!
# calculated audio features for participant 310!
# calculated audio features for participant 312!
# calculated audio features for participant 313!
# calculated audio features for participant 315!
# calculated audio features for participant 316!
# calculated audio features for participant 317!
# calculated audio features for participant 318!
# calculated audio features for participant 319!
# calculated audio features for participant 320!
# calculated audio features for participant 321!
# calculated audio features for participant 322!
# calculated audio features for participant 324!
# calculated audio features for participant 325!
# calculated audio features for participant 326!
# calculated audio features for participant 327!
# calculated audio features for participant 328!
# calculated audio features for participant 330!
# calculated audio features for participant 333!
# calculated audio features for participant 336!
# calculated audio features for participant 338!
# calculated audio features for participant 339!
# calculated audio features for participant 340!
# calculated audio features for participant 341!
# calculated audio features for participant 343!
# calculated audio features for participant 344!
# calculated audio features for participant 345!
# calculated audio features for participant 347!
# calculated audio features for participant 348!
# calculated audio features for participant 350!
# calculated audio features for participant 351!
# calculated audio features for participant 352!
# calculated audio features for participant 353!
# calculated audio features for participant 355!
# calculated audio features for participant 356!
# calculated audio features for participant 357!
# calculated audio features for participant 358!
# calculated audio features for participant 360!
# calculated audio features for participant 362!
# calculated audio features for participant 363!
# calculated audio features for participant 364!
# calculated audio features for participant 366!
# calculated audio features for participant 368!
# calculated audio features for participant 369!
# calculated audio features for participant 370!
# calculated audio features for participant 371!
# calculated audio features for participant 372!
# calculated audio features for participant 374!
# calculated audio features for participant 375!
# calculated audio features for participant 376!
# calculated audio features for participant 379!
# calculated audio features for participant 380!
# calculated audio features for participant 383!
# calculated audio features for participant 385!
# calculated audio features for participant 386!
# calculated audio features for participant 391!
# calculated audio features for participant 392!
# calculated audio features for participant 393!
# calculated audio features for participant 397!
# calculated audio features for participant 400!
# calculated audio features for participant 401!
# calculated audio features for participant 402!
# calculated audio features for participant 409!
# calculated audio features for participant 412!
# calculated audio features for participant 414!
# calculated audio features for participant 415!
# calculated audio features for participant 416!
# calculated audio features for participant 419!
# calculated audio features for participant 423!
# calculated audio features for participant 425!
# calculated audio features for participant 426!
# calculated audio features for participant 427!
# calculated audio features for participant 428!
# calculated audio features for participant 429!
# calculated audio features for participant 430!
# calculated audio features for participant 433!
# calculated audio features for participant 434!
# calculated audio features for participant 437!
# calculated audio features for participant 441!
# calculated audio features for participant 443!
# calculated audio features for participant 444!
# calculated audio features for participant 445!
# calculated audio features for participant 446!
# calculated audio features for participant 447!
# calculated audio features for participant 448!
# calculated audio features for participant 449!
# calculated audio features for participant 454!
# calculated audio features for participant 455!
# calculated audio features for participant 456!
# calculated audio features for participant 457!
# calculated audio features for participant 459!
# calculated audio features for participant 463!
# calculated audio features for participant 464!
# calculated audio features for participant 468!
# calculated audio features for participant 471!
# calculated audio features for participant 473!
# calculated audio features for participant 474!
# calculated audio features for participant 475!
# calculated audio features for participant 478!
# calculated audio features for participant 479!
# calculated audio features for participant 485!
# calculated audio features for participant 486!
# calculated audio features for participant 487!
# calculated audio features for participant 488!
# calculated audio features for participant 491!
# calculated all audio features with librosa!

# %% [markdown]
# # store feature results on disk

# %%
if PARTICIPANTS_INFO_EXIST_ON_DISK == False:
    updated_participant_info = PARTICIPANTS_INFO.copy()
    for v in updated_participant_info.values():
        if 'loaded_audio_30s' in v:
            del v['loaded_audio_30s']
        for audio_feat in AUDIO_FEATURES:
            v[audio_feat] = float(v[audio_feat])
    with open('extracted_feature_results/results.json', 'w') as jsonFile:
        json.dump(updated_participant_info, jsonFile)

# %% [markdown]
# # compute statistics

# %%
group_stats = {'male': {
    'x': [],
    'x_ber_mean': [],
    'x_ber_median': [],
    'zcr_median': [],
    'zcr_mean': [],
    'rmse_median': [],
    'rmse_mean': [],
    'f0_median': [],
    'f0_mean': [],
    'f0_range': [],
    'ber_median': [],
    'ber_mean': [],
    'spearman_coeffs': {}
}, 'female': {
    'x': [],
    'x_ber_mean': [],
    'x_ber_median': [],
    'zcr_median': [],
    'zcr_mean': [],
    'rmse_median': [],
    'rmse_mean': [],
    'f0_median': [],
    'f0_mean': [],
    'f0_range': [],
    'ber_median': [],
    'ber_mean': [],
    'spearman_coeffs': {}
}}

depressed = 0
healthy = 0
males = 0
females = 0

for v in PARTICIPANTS_INFO.values():
    if v['depressed'] == "yes":
        depressed += 1
    else:
        healthy += 1
    if v['gender'] == 'male':
        males += 1
    else:
        females += 1

for v in PARTICIPANTS_INFO.values():
    if v['gender'] == 'male':
        group_stats['male']['x'].append(int(v['phq_score']))
        for audio_feat in AUDIO_FEATURES:
            if audio_feat not in ['ber_median, ber_mean']:
                group_stats['male'][audio_feat].append(v[audio_feat])
        if not np.isnan(v['ber_median']):
            group_stats['male']['x_ber_median'].append(int(v['phq_score']))
            group_stats['male']['ber_median'].append(v['ber_median'])
        if not np.isnan(v['ber_mean']):
            group_stats['male']['x_ber_mean'].append(int(v['phq_score']))
            group_stats['male']['ber_mean'].append(v['ber_mean'])
    elif v['gender'] == 'female':
        group_stats['female']['x'].append(int(v['phq_score']))
        for audio_feat in AUDIO_FEATURES:
            if audio_feat not in ['ber_median, ber_mean']:
                group_stats['female'][audio_feat].append(v[audio_feat])
        if not np.isnan(v['ber_median']):
            group_stats['female']['x_ber_median'].append(int(v['phq_score']))
            group_stats['female']['ber_median'].append(v['ber_median'])
        if not np.isnan(v['ber_mean']):
            group_stats['female']['x_ber_mean'].append(int(v['phq_score']))
            group_stats['female']['ber_mean'].append(v['ber_mean'])

# spearman correlation
# scipy spearman returns correlation and p-value
# pvalue: The p-value for a hypothesis test whose null hypotheisis is that two sets of data are uncorrelated. See alternative above for alternative hypotheses. pvalue has the same shape as correlation.

# males
for k, v in group_stats['male'].items():
    if k not in ['x', 'ber_median', 'ber_mean', 'spearman_coeffs', 'x_ber_mean', 'x_ber_median']:
        corr_sp = stats.spearmanr(group_stats['male']['x'], group_stats['male'][k])
        group_stats['male']['spearman_coeffs'][k] = corr_sp

# females
for k, v in group_stats['female'].items():
    if k not in ['x', 'ber_median', 'ber_mean', 'spearman_coeffs', 'x_ber_mean', 'x_ber_median']:
        corr_sp = stats.spearmanr(group_stats['female']['x'], group_stats['female'][k])
        group_stats['female']['spearman_coeffs'][k] = corr_sp
        
print(group_stats['male']['spearman_coeffs'])
print(group_stats['female']['spearman_coeffs'])
# Out:
# {'zcr_median': SpearmanrResult(correlation=0.007821903644852773, pvalue=0.9378082215372282), 'zcr_mean': SpearmanrResult(correlation=0.1443970126422387, pvalue=0.14762677130375887), 'rmse_median': SpearmanrResult(correlation=-0.07327380926039329, pvalue=0.46423368031676315), 'rmse_mean': SpearmanrResult(correlation=-0.03958476677770492, pvalue=0.6928323760423404), 'f0_median': SpearmanrResult(correlation=0.03990783771560005, pvalue=0.6904527575080002), 'f0_mean': SpearmanrResult(correlation=0.03573750876805986, pvalue=0.7213936905402172), 'f0_range': SpearmanrResult(correlation=0.024530525627869608, pvalue=0.8066657896232594)}
# {'zcr_median': SpearmanrResult(correlation=-0.15126720909290586, pvalue=0.16193849619244485), 'zcr_mean': SpearmanrResult(correlation=0.03412064752269331, pvalue=0.7537151612353294), 'rmse_median': SpearmanrResult(correlation=-0.14180087176404418, pvalue=0.19015135424246718), 'rmse_mean': SpearmanrResult(correlation=-0.0857787433860092, pvalue=0.42954170734315855), 'f0_median': SpearmanrResult(correlation=-0.03693929848069748, pvalue=0.7340979944891189), 'f0_mean': SpearmanrResult(correlation=-0.07016931512015541, pvalue=0.5183919667960737), 'f0_range': SpearmanrResult(correlation=-0.13685666761192072, pvalue=0.2062272334749501)}

# %% [markdown]
# # plot data

# %%
def plot_scatter(x, y, x_label, y_label, plot_title, x_ticks=None, axis_font_size=11, ticks_font_size=10):
    plt.figure(figsize=(15, 6))
    plt.scatter(x, y)
    plt.xlabel(x_label, fontsize=axis_font_size)
    plt.ylabel(y_label, fontsize=axis_font_size)
    plt.xticks(x_ticks)
    plt.grid(True)
    plt.xticks(fontsize=ticks_font_size)
    plt.yticks(fontsize=ticks_font_size)
    plt.title(plot_title, fontsize=axis_font_size)
    plt.text(21, 0.06, 'matplotlib')
    #plt.gca().xaxis.set_major_formatter(StrMethodFormatter('{x:,.0f}')) # No decimal places
    plt.show()


# plot for males
for k, v in group_stats['male'].items():
    if k not in ['x', 'ber_median', 'ber_mean', 'spearman_coeffs', 'x_ber_mean', 'x_ber_median']:
        plot_scatter(group_stats['male']['x'], 
                 v, 
                 'PHQ score', k.replace('_', ' '),'male', 
                 x_ticks=range(0, 25),
                 axis_font_size=16,
                 ticks_font_size=12)


# plot for females
for k, v in group_stats['female'].items():
    if k not in ['x', 'ber_median', 'ber_mean', 'spearman_coeffs', 'x_ber_mean', 'x_ber_median']:
        plot_scatter(group_stats['female']['x'], 
                 v, 
                 'PHQ score', k.replace('_', ' '),'female', 
                 x_ticks=range(0, 25),
                 axis_font_size=16,
                 ticks_font_size=12)        
        
        
        
        
# plt.figure(figsize=(15, 50))
# ax = plt.subplot(9, 1, 1)
# plt.subplots_adjust(wspace=0.5,hspace=0.5)
# plt.scatter(x, y_zcr_median)
# plt.xlabel("PHQ score", fontsize=16)
# plt.xticks(range(0, 25))
# plt.ylabel("Zero crossing rate (median)", fontsize=16)
# plt.title(f"Correlation = {r_zcr_median}")
# plt.vlines(9.5, min(y_zcr_median), max(y_zcr_median), linestyles='dashed')

# plt.subplot(9, 1, 2)
# plt.scatter(x, y_zcr_mean)
# plt.xlabel("PHQ score", fontsize=16)
# plt.xticks(range(0, 25))
# plt.ylabel("Zero crossing rate (mean)", fontsize=16)
# plt.title(f"Correlation = {r_zcr_mean}")
# plt.vlines(9.5, min(y_zcr_mean), max(y_zcr_mean), linestyles='dashed')
